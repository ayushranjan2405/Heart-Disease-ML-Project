# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np 
import matplotlib.pyplot as plt

objects = ('NAIVE BAYES', 'K-MEAN', 'KNN','LOGISTIC REGRESSION', 'SVM', 'DECISION TREE')
y_pos =np.arange(len(objects))
performance = [0.714,0.417,0.824,0.802,0.802,0.791]
plt.barh(y_pos, performance, align='center', alpha=1) 
plt.yticks(y_pos, objects)
plt.xlabel('Accuracy')
plt.title('ACCURACY OF ALGORITHMS')
plt.show()

n_groups = 6
support_1 = (42,28,53,53,55,50) 
support_0 = (49, 63, 38,38,36,41 )
fig, ax =plt.subplots() 
index = np.arange(n_groups) 
bar_width = 0.35
opacity = 0.8
rects1 = plt.bar(index, support_1, bar_width, alpha=opacity,color='b',label='1')
rects2 = plt.bar(index + bar_width, support_0,
bar_width,alpha=opacity,color='g',label='0')
plt.xlabel('Algorithms')
plt.ylabel('Support')
plt.title('Comparion on Support of Algorithms')
plt.xticks(index + bar_width, ('NAIVE BAYES', 'K-MEAN', 'KNN', 'LR', 'SVM','DECISION TREE'))
support_1 = (0.66,0.23,0.89,0.87,0.89,0.83)
support_0 = (0.78, 0.61, 0.75,0.73,0.70, 0.75)
fig, ax = plt.subplots()
index=np.arange(n_groups)
bar_width = 0.35
opacity = 0.8 
rects1 =plt.bar(index, support_1, bar_width,alpha=opacity, color='b', label='1')
rects2 = plt.bar(index + bar_width, support_0, bar_width, alpha=opacity, color='g',
label='0') 
plt.xlabel('Algorithms')
plt.ylabel('Precision')
plt.title('Comparion on Precision of Algorithms')
plt.xticks(index + bar_width, ('NAIVE BAYES', 'K-MEAN', 'KNN', 'LR', 'SVM','DECISION TREE'))
plt.legend() 
plt.tight_layout()
plt.show()

n_groups = 6
support_1 = (0.79,0.39,0.79,0.77,0.76,0.78)
support_0 = (0.65, 0.43, 0.87,0.84,0.86, 0.80)
fig, ax = plt.subplots() 
index =np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
rects1 = plt.bar(index, support_1, bar_width, alpha=opacity, color='b', label='1')
rects2 = plt.bar(index + bar_width, support_0, bar_width, alpha=opacity, color='g',label='0')
plt.xlabel('Algorithms') 
plt.ylabel('Recall') 
support_1 = (0.72,0.29,0.84,0.82,0.82,0.80)
support_0 = (0.71, 0.50, 0.80,0.78,0.78, 0.78)
fig, ax = plt.subplots() 
index =np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
rects1 = plt.bar(index, support_1, bar_width, alpha=opacity, color='b', label='1')
rects2 = plt.bar(index + bar_width, support_0, bar_width, alpha=opacity, color='g',label='0')
plt.xlabel('Algorithms') 
plt.ylabel('f1-score')
plt.title('Comparion on f1-score of Algorithms')
plt.xticks(index + bar_width, ('NAIVE BAYES', 'K-MEAN', 'KNN', 'LR', 'SVM','DECISION TREE'))
plt.legend()
plt.tight_layout()
plt.show()
